# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahal09/Python/blob/main/Project_Week_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Installing the libraries with the specified version.
# !pip install numpy==1.25.2 pandas==1.5.3 matplotlib==3.7.1 seaborn==0.13.1 -q --user

# %%
# Import libraries for data manipulation
import numpy as np
import pandas as pd

# Import libraries for data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Command to tell Python to actually display the graphs
# %matplotlib inline

pd.set_option('display.float_format', lambda x: '%.2f' % x) # To supress numerical display in scientific notations

# %%
# Write your code here to read the data

df =pd.read_csv('/content/foodhub_order.csv') #This is the code to read the contents of the .csv file in google colab.

# %% [markdown]
# OBSERVATION
#
# 1. For the above line of code, I have directly uploaded by .csv file in the
# upload to session storage folder(same working directory).It is helpful to read the contents of the .csv file in google colab.**bold text**

# %%
# Write your code here to view the first 5 rows
df.head()
# Out:
#    order_id  customer_id            restaurant_name cuisine_type  \
# 0   1477147       337525                    Hangawi       Korean
# 1   1477685       358141  Blue Ribbon Sushi Izakaya     Japanese
# 2   1477070        66393                Cafe Habana      Mexican
# 3   1477334       106968  Blue Ribbon Fried Chicken     American
# 4   1478249        76942           Dirty Bird to Go     American
#
#    cost_of_the_order day_of_the_week     rating  food_preparation_time  \
# 0              30.75         Weekend  Not given                     25
# 1              12.08         Weekend  Not given                     25
# 2              12.23         Weekday          5                     23
# 3              29.20         Weekend          3                     25
# 4              11.59         Weekday          4                     25
#
#    delivery_time
# 0             20
# 1             23
# 2             28
# 3             15
# 4             24

# %% [markdown]
# OBSERVATION:
# The head() in Python is used to display the first few rows of a DataFrame. By default, it shows the first 5 rows.

# %%
#Question 1: How many rows and columns are present in the data? [0.5 mark]

df.shape  # It helps to  return the number of rows and columns in the dataframe.
# Out:
# (1898, 9)

# %% [markdown]
# OBSERVATIONS:
#
# shape is useful when you want to quickly check the size of your DataFrame, especially when working with large datasets. It helps you understand how many rows (data entries) and columns (features) the dataset contains.

# %%
#Question 2: What are the datatypes of the different columns in the dataset? [0.5 mark]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1898 entries, 0 to 1897
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   order_id               1898 non-null   int64
#  1   customer_id            1898 non-null   int64
#  2   restaurant_name        1898 non-null   object
#  3   cuisine_type           1898 non-null   object
#  4   cost_of_the_order      1898 non-null   float64
#  5   day_of_the_week        1898 non-null   object
#  6   rating                 1898 non-null   object
#  7   food_preparation_time  1898 non-null   int64
#  8   delivery_time          1898 non-null   int64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 133.6+ KB

# %%
#Question 3: Are there any missing values in the data? If yes, treat them using an appropriate method. [1 mark]
df.isnull().sum()
# Out:
# order_id                 0
# customer_id              0
# restaurant_name          0
# cuisine_type             0
# cost_of_the_order        0
# day_of_the_week          0
# rating                   0
# food_preparation_time    0
# delivery_time            0
# dtype: int64

# %%
#Question 4: Check the statistical summary of the data. What is the minimum, average, and maximum time it takes for food to be prepared once an order is placed? [2 marks]
df['food_preparation_time'].describe()
# Out:
# count   1898.00
# mean      27.37
# std        4.63
# min       20.00
# 25%       23.00
# 50%       27.00
# 75%       31.00
# max       35.00
# Name: food_preparation_time, dtype: float64

# %%
'''Question 4: Check the statistical summary of the data.
  What is the minimum, average, and maximum time it takes for food to be prepared once an order is placed? [2 marks]

 TRIED ANOTHER METHOD USING PYTHON,'''

min_order =df['food_preparation_time'].min()
avg_order =df['food_preparation_time'].mean()
max_order =df['food_preparation_time'].max()
print(f'The minimum time it takes for the food to be prepared is {min_order} mintues')
print(f'The average time it takes for the food to be prepared is {avg_order} minutes')
print(f'The Maximum time it takes for the food to be  prepared is {max_order} minutes')
# Out:
# The minimum time it takes for the food to be prepared is 20 mintues
# The average time it takes for the food to be prepared is 27.371970495258168 minutes
# The Maximum time it takes for the food to be  prepared is 35 minutes

# %%
# Question 5: How many orders are not rated? [1 mark]
df['rating'].value_counts()
# Out:
# rating
# Not given    736
# 5            588
# 4            386
# 3            188
# Name: count, dtype: int64

# %%
'''
Observations: Exploratory Data Analysis (EDA) Univariate Analysis

Question 6: Explore all the variables and provide observations on their distributions.
(Generally, histograms, boxplots, countplots, etc. are used for univariate exploration.) [9 marks]'''

# %%
#Question 6:
#Find the Unique values of order_ID

df['order_id'].unique()
# Out:
# array([1477147, 1477685, 1477070, ..., 1477819, 1477513, 1478056])

# %%
#Question 6:
#Find the nunique values of order_ID

df['order_id'].nunique()
# Out:
# 1898

# %%
#Question 6:
#Find the Unique values of Customer_id

df['customer_id'].unique()
# Out:
# array([337525, 358141,  66393, ...,  97838, 292602, 397537])

# %%
#Question 6:
#Find the nunique values of customer_id

df['customer_id'].nunique()
# Out:
# 1200

# %%
##Find the nunique values of restaurant name
df['restaurant_name'].nunique()
# Out:
# 178

# %%
##Find the unique values of restaurant name
df['restaurant_name'].unique()

# %%
#Question 6:
#Find the Unique values of food preparation time.

df['food_preparation_time'].unique()
# Out:
# array([25, 23, 20, 28, 33, 21, 29, 34, 24, 30, 35, 32, 31, 27, 22, 26])

# %%
#Question 6:
#Find the nunique values of food preparation time.

df['food_preparation_time'].nunique()
# Out:
# 16

# %%
#Question 6:
#Find the Unique values of rating
df['rating'].unique()
# Out:
# array(['Not given', '5', '3', '4'], dtype=object)

# %%
#Question 6:
#Find the Unique values of day_of_week

df['day_of_the_week'].unique()
#
# Out:
# array(['Weekend', 'Weekday'], dtype=object)

# %%
#Question 6:
plt.figure(figsize=(7, 7))
sns.histplot(data =df, x ='order_id',kde=True)
plt.show()
sns.boxplot(data =df, x ='order_id')
plt.show()

# %%
sns.histplot(data=df,x='customer_id',kde=True)
plt.show()
sns.boxplot(data=df,x='customer_id')
plt.show()

# %%
sns.histplot(data =df, x ='food_preparation_time',kde=True)
plt.show()
sns.boxplot(data =df, x ='food_preparation_time')
plt.show()
sns.countplot(data =df, x ='food_preparation_time')
plt.show()
#

# %%
sns.histplot(data =df, x ='cost_of_the_order',kde=True)
plt.show()
sns.boxplot(data =df, x ='cost_of_the_order')
plt.show()
sns.countplot(data =df, x ='cost_of_the_order')
plt.show()

# %%
sns.histplot(data =df, x ='delivery_time',kde=True)
plt.show()
sns.boxplot(data =df, x ='delivery_time')
plt.show()
sns.countplot(data =df, x ='delivery_time')
# Out:
# <Axes: xlabel='delivery_time', ylabel='count'>

# %%
sns.histplot(data =df, x ='rating',kde=True)
plt.show()
sns.boxplot(data =df, x ='rating')
plt.show()
sns.countplot(data =df, x ='rating')
# Out:
# <Axes: xlabel='rating', ylabel='count'>

# %%
sns.pairplot(df,diag_kind="kde")

# %%
#Question 7: Which are the top 5 restaurants in terms of the number of orders received? [1 mark]

df['restaurant_name'].value_counts().head(5)
# Out:
# restaurant_name
# Shake Shack                  219
# The Meatball Shop            132
# Blue Ribbon Sushi            119
# Blue Ribbon Fried Chicken     96
# Parm                          68
# Name: count, dtype: int64

# %%
#Question 8: Which is the most popular cuisine on weekends? [1 mark]

df['cuisine_type'].unique()

Weekend_popular = df[df['day_of_the_week'] == 'Weekend']
popular_Cuisine_weekend = Weekend_popular.groupby(['cuisine_type'])[['day_of_the_week']].count().head(1)
popular_Cuisine_weekend
# Out:
#               day_of_the_week
# cuisine_type
# American                  415

# %%
# Question 9: What percentage of the orders cost more than 20 dollars? [2 marks]

total_orders = (df['cost_of_the_order']>20).value_counts()
print(total_orders)

percentage = (df['cost_of_the_order'].sort_values(ascending = False) >20).mean()*100
print(f'Percentage of orders that cost above $20 is {percentage:.3f} %')
# Out:
# Percentage of orders that cost above $20 is 29.241 %

# %%
# Question 10: What is the mean order delivery time? [1 mark]

avg_delivery_time = df['delivery_time'].mean().round(2)
print(f'The mean order of delivery time is {avg_delivery_time} minutes')
# Out:
# The mean order of delivery time is 24.16 minutes

# %%
#Question 11: The company has decided to give 20% discount vouchers to the top 3 most frequent customers.
#Find the IDs of these customers and the number of orders they placed. [1 mark]

cust = df.groupby('customer_id')['order_id'].count().sort_values(ascending = False).head(3)
cust
# Out:
# customer_id
# 52832    13
# 47440    10
# 83287     9
# Name: order_id, dtype: int64

# %%
#    Multivariate Analysis
#Question 12: Perform a multivariate analysis to explore relationships between the important variables in the dataset.
#(It is a good idea to explore relations between numerical variables
 ## as well as relations between numerical and categorical variables) [10 marks]

# Understanding the distribution on weekdays and weekends.
sns.countplot(data=df,x='day_of_the_week',hue='day_of_the_week')
plt.show()

# %% [markdown]
# *   The number of orders are more on weekends than on weekdays'
#
# * The Number of orders on weekends is around 1350 while the number of orders on weekdays is around 570.

# %%
# Understanding the cuisine type and the Day of the week combination
#and applying "day_of_the_week" for hue.
sns.countplot(data=df, x='cuisine_type', hue='day_of_the_week')
plt.xticks(rotation=90);

# %%
# Understanding how the ratings are given for different cuisines.

sns.boxplot(data=df,x='cuisine_type',hue='rating')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left') # Place the legend outside the plot
plt.xticks(rotation=90);

# %%
#Below is the relationship between food preparation time and during weekdays and weekdays.

sns.lineplot(data=df,x='food_preparation_time',y='day_of_the_week')
plt.show()

# %%
sns.barplot(data=df,x='cuisine_type',y='cost_of_the_order',hue='cuisine_type')
plt.xticks(rotation=90);

# %% [markdown]
# OBSERVATIONS:

# %%
# Observations from sns.lineplot(data=df,x='food_preparation_time',y='day_of_the_week')
# This line plot visualizes the relationship between food preparation time and the day of the week.
# It helps understand if there are any patterns or trends in food preparation time depending on whether it's a weekday or weekend.
#
# Possible observations:
# 1. **Average Food Preparation Time on Weekdays vs Weekends:**
#    - If the line for weekends is generally higher than the line for weekdays, it suggests that food preparation takes longer on average during weekends.
#    - Conversely, if the line for weekdays is higher, it suggests that food preparation takes longer on weekdays.
# 2. **Fluctuations in Preparation Time:**
#    - The plot can show if there are any specific periods within weekdays or weekends when preparation time tends to increase or decrease.
#    - For instance, you might observe a spike in preparation time during lunch or dinner hours on both weekdays and weekends.
# 3. **Overall Trend:**
#    - If the lines show a general upward or downward trend, it suggests a consistent change in preparation time over the course of the week.
#    - For example, if the line has an upward trend throughout the week, it indicates a gradual increase in the average preparation time as the week progresses.
#
# **Important Note:**
# To make meaningful observations, you need to examine the plot carefully and consider the context of the data. It's recommended to also consider other factors that might influence food preparation time, such as the type of cuisine, restaurant popularity, and peak demand periods.

# %%
sns.pointplot(data=df,x='rating',y='delivery_time')
plt.show()
# Out:
# <Axes: xlabel='rating', ylabel='delivery_time'>

# %%
# Below is the relationship between the food preparation time and delivery time
# explained in the Boxplot.

sns.boxplot(data=df,x='food_preparation_time',y='delivery_time')
#
# Out:
# <Axes: xlabel='food_preparation_time', ylabel='delivery_time'>

# %%
# Below is the Heatmap generated for the numerical values to see correlation
# between 'food_preparation_time','cost_of_the_order','delivery_time'

correlation = df[['food_preparation_time','cost_of_the_order','delivery_time']]
sns.heatmap(correlation.corr(),annot=True,cmap='Spectral')
# Out:
# <Axes: >

# %%
#Question 13:
#The company wants to provide a promotional offer in the advertisement of the restaurants.
#The condition to get the offer is that the restaurants must have a rating count of more than 50 and the average rating should be greater than 4.
#Find the restaurants fulfilling the criteria to get the promotional offer. [3 marks]

# %%
# Filtering the rated restaurants
rating_count = df[df['rating'] != 'Not given'].copy()

# Below code helps to Convert rating column from object to integer
rating_count['rating'] = rating_count['rating'].astype('int')

# Creating a dataframe that contains the restaurant names with their rating counts
df_rating_count = rating_count.groupby(['restaurant_name'])['rating'].count().sort_values(ascending = False).reset_index()
df_rating_count.head()
# Out:
#              restaurant_name  rating
# 0                Shake Shack     133
# 1          The Meatball Shop      84
# 2          Blue Ribbon Sushi      73
# 3  Blue Ribbon Fried Chicken      64
# 4           RedFarm Broadway      41

# %%
# Get the restaurant names that have rating count more than 50
rest_names = df_rating_count[df_rating_count['rating']>50]['restaurant_name']
rest_names

# Filter to get the data of restaurants that have rating count more than 50
df_mean_4 = rating_count[rating_count['restaurant_name'].isin(rest_names)].copy()

# Group the restaurant names with their ratings and find the mean rating of each restaurant
df_mean_4_rating = df_mean_4.groupby(['restaurant_name'])['rating'].mean().sort_values(ascending = False).reset_index().dropna() # Group by 'restaurant_name' and calculate the mean of 'rating'

# filter for average rating greater than 4
df_avg_rating_greater_than_4 = df_mean_4_rating[df_mean_4_rating['rating'] > 4].sort_values(by='rating', ascending=False).reset_index(drop=True)  ## Complete the code to find restaurants with rating > 4

df_avg_rating_greater_than_4
# Out:
#              restaurant_name  rating
# 0          The Meatball Shop    4.51
# 1  Blue Ribbon Fried Chicken    4.33
# 2                Shake Shack    4.28
# 3          Blue Ribbon Sushi    4.22

# %%
#Question 14: The company charges the restaurant 25% on the orders having cost greater than 20 dollars and
#15% on the orders having cost greater than 5 dollars.
#Find the net revenue generated by the company across all orders. [3 marks]

def calculate_revenue(cost):
    if cost > 20:
        return cost * 0.25  # 25% commission
    elif cost > 5:
        return cost * 0.15  # 15% commission
    else:
        return 0  # No commission for cost <= 5

# Apply the function to calculate the revenue for each order
df['revenue'] = df['cost_of_the_order'].apply(calculate_revenue)

# Calculate the total revenue by summing the revenue column
total_revenue = df['revenue'].sum()

# Output the total revenue
print(f'Total revenue generated by the company: ${total_revenue:.2f}')
# Out:
# Total revenue generated by the company: $6166.30

# %% [markdown]
# Observations:
#
# The calculate_revenue function applies the appropriate percentage based on the order cost.
#
# The .apply() function applies this logic to every row in the DataFrame.
#
# Finally, the .sum() function totals the revenue for all orders.

# %%
#Question 15: The company wants to analyze the total time required to deliver the food.
#What percentage of orders take more than 60 minutes to get delivered from the time the order is placed?
#(The food has to be prepared and then delivered.) [2 marks]

df['total_time_required'] = df['delivery_time']+df['food_preparation_time']

time_more_60_min = (df['total_time_required']>60).value_counts()
print(time_more_60_min)

percentage = (df['total_time_required'].sort_values(ascending = False) >60).mean()*100
print(f'Percentage of orders that take more than 60 minutes is {percentage:.3f} %')
# Out:
# Percentage of orders that take more than 60 minutes is 10.537 %

# %%
#Question 16:
#The company wants to analyze the delivery time of the orders on weekdays and weekends.
#Question 16:
#The company wants to analyze the delivery time of the orders on weekdays and weekends.
#How does the mean delivery time vary during weekdays and weekends? [2 marks]

if 'Weekday' in df['day_of_the_week'].values:
  mean_delivery_weekday=df[df['day_of_the_week'] == 'Weekday']['delivery_time'].mean()
  print(f'The mean delivery time during weekdays is {mean_delivery_weekday:.2f} minutes')

if 'Weekend' in df['day_of_the_week'].values:
  mean_delivery_weekend=df[df['day_of_the_week'] == 'Weekend']['delivery_time'].mean()
  print(f'The mean delivery time during weekends is {mean_delivery_weekend:.2f} minutes')
# Out:
# The mean delivery time during weekdays is 28.34 minutes
# The mean delivery time during weekends is 22.47 minutes
